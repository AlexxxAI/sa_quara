# %%
# !pip install fastapi uvicorn pandas openpyxl pydantic catboost shap joblib
# Out:
# Requirement already satisfied: fastapi in c:\users\alexxx\anaconda3\lib\site-packages (0.121.1)
# Requirement already satisfied: uvicorn in c:\users\alexxx\anaconda3\lib\site-packages (0.38.0)
# Requirement already satisfied: pandas in c:\users\alexxx\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\alexxx\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: pydantic in c:\users\alexxx\anaconda3\lib\site-packages (2.10.3)
# Requirement already satisfied: catboost in c:\users\alexxx\anaconda3\lib\site-packages (1.2.8)
# Requirement already satisfied: shap in c:\users\alexxx\anaconda3\lib\site-packages (0.49.1)
# Requirement already satisfied: joblib in c:\users\alexxx\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in c:\users\alexxx\anaconda3\lib\site-packages (from fastapi) (0.49.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\alexxx\anaconda3\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\alexxx\anaconda3\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alexxx\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\alexxx\anaconda3\lib\site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\alexxx\anaconda3\lib\site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.7.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alexxx\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alexxx\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: click>=7.0 in c:\users\alexxx\anaconda3\lib\site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in c:\users\alexxx\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alexxx\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexxx\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexxx\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexxx\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\alexxx\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: graphviz in c:\users\alexxx\anaconda3\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\alexxx\anaconda3\lib\site-packages (from catboost) (3.10.0)
# Requirement already satisfied: scipy in c:\users\alexxx\anaconda3\lib\site-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in c:\users\alexxx\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\alexxx\anaconda3\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: scikit-learn in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (1.6.1)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in c:\users\alexxx\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\alexxx\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\alexxx\anaconda3\lib\site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alexxx\anaconda3\lib\site-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\alexxx\anaconda3\lib\site-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alexxx\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
# import uvicorn

# if __name__ == "__main__":
#     uvicorn.run("app:app", host="127.0.0.1", port=8000, reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['C:\\Users\\Alexxx\\work\\zyplai\\sa_quara\\code']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [57360] using StatReload
# INFO:     Stopping reloader process [57360]

# %%
import threading
import uvicorn
import os, sys

# os.chdir("/path/to/sa_quara") 

os.chdir("..")
sys.path.append(os.getcwd())

def run():
    uvicorn.run("app:app", host="127.0.0.1", port=8000, reload=False)

thread = threading.Thread(target=run, daemon=True)
thread.start()
# Out:
# INFO:     Started server process [95624]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:57610 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:57610 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52760 - "POST /predict HTTP/1.1" 200 OK
