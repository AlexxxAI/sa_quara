# %%
import sys
# !{sys.executable} -m pip install python-multipart
# Out:
# ...
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import uvicorn

if __name__ == "__main__":
    uvicorn.run("app:app", host="127.0.0.1", port=8000, reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['c:\\Users\\Alexxx\\work\\zyplai\\sa_quara\\code']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [58496] using StatReload

# %%
import requests

url = "http://127.0.0.1:8000/predict"
files = {"file": open("../data/jarir_sample100.xlsx", "rb")}
data = {"product": "jarir", "threshold": 0.3}

response = requests.post(url, files=files, data=data)
open("predictions/jarir_sample100_predictions.xlsx", "wb").write(response.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Alexxx\Python\python3.12.3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\Alexxx\Python\python3.12.3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\Alexxx\Python\python3.12.3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
# ...
